# %% [markdown]
# ``Leyenda:``
# - df corresponde al archivo complementario
# - df3 corresponde al archivo principal
#
# - Plantear modificar variables para hacerlo más claro

# %% [markdown]
# ## Lectura del archivo complementario (n_movies):

# %%
import pandas as pd

# %%
df = pd.read_csv("n_movies.csv")

# %%
import os
print(os.getcwd())  # Esto te muestra en qué carpeta estás trabajando
# Out:
# c:\Users\Usuario\Documents\Adalab49\Módulo 4\Modulo-4_Proyecto-Tableau_Maria_Maleni

# %%
# Pedir opinion: mantener index_col=0 para dejar el titulo como indice?

df.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %%
df.sample(20)
# Out:
#                                                   title         year  \
# 8617                                          Cobra Kai     (2018– )
# 824                                       Blood Red Sky       (2021)
# 5003        Jane Fonda & Lily Tomlin: Ladies Night Live       (2022)
# 6347                           Bruna Louise: Demolition       (2022)
# 6457                                          The Tapes       (2020)
# 1158                                           Dumplin'       (2018)
# 7648  Dennis Nilsen's the History of A Drowning Boy ...          NaN
# 4435                           Sword Gai: The Animation       (2018)
# 3143                            Olaf's Frozen Adventure       (2017)
# 6613                                        Juana Brava       (2015)
# 9850                                              Lupin     (2021– )
# 4268                                         Black Snow       (2017)
# 1664                         Scrooge: A Christmas Carol       (2022)
# ...

# %%
df.shape
# Out:
# (9957, 9)

# %%
df.columns
# Out:
# Index(['title', 'year', 'certificate', 'duration', 'genre', 'rating',
#        'description', 'stars', 'votes'],
#       dtype='object')

# %%
df['genre'].unique()
# Out:
# array(['Action, Comedy, Drama', 'Biography, Drama, History',
#        'Crime, Drama', 'Drama, Horror, Mystery',
#        'Animation, Action, Adventure', 'Drama, Fantasy, Horror',
#        'Animation, Adventure, Comedy', 'Crime, Drama, Thriller',
#        'Action, Adventure, Drama', 'Biography, Drama, Mystery',
#        'Action, Crime, Drama', 'Drama, Horror, Thriller',
#        'Crime, Drama, Mystery', 'Comedy', 'Thriller',
#        'Drama, Romance, Sport', 'Drama, History, Horror',
#        'Drama, Romance', 'Drama, Horror, Sci-Fi',
#        'Action, Biography, Crime', 'Comedy, Romance', 'Comedy, Drama',
#        'Comedy, Drama, Romance', 'Drama, Mystery, Thriller',
#        'Action, Thriller', 'Crime, Drama, Fantasy',
#        'Action, Adventure, Comedy', 'Action, Drama, History', 'Drama',
#        'Drama, Mystery, Sci-Fi', 'Comedy, Crime',
#        'Action, Drama, Mystery', 'Drama, Fantasy, Romance',
#        'Action, Comedy, Fantasy', 'Animation, Drama, Family',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9957 entries, 0 to 9956
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        9957 non-null   object
#  1   year         9430 non-null   object
#  2   certificate  6504 non-null   object
#  3   duration     7921 non-null   object
#  4   genre        9884 non-null   object
#  5   rating       8784 non-null   float64
#  6   description  9957 non-null   object
#  7   stars        9957 non-null   object
#  8   votes        8784 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 700.2+ KB

# %% [markdown]
# ``Cantidad de nulos de las columnas``

# %%
df.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64

# %% [markdown]
# ``Función para cambiar la columna title a minúsculas`` (y evitar problemas en la vinculación de df)

# %%
def convertir_minusculas(df):
  
    if 'title' in df.columns:
        df['title'] = df['title'].str.lower()
    else:
        print("La columna 'title' no existe en el DataFrame.")
    
    return df

# %%
df = convertir_minusculas(df)

# %%
df.head()
# Out:
#                     title         year certificate duration  \
# 0               cobra kai     (2018– )       TV-14   30 min
# 1               the crown     (2016– )       TV-MA   58 min
# 2        better call saul  (2015–2022)       TV-MA   46 min
# 3           devil in ohio       (2022)       TV-MA  356 min
# 4  cyberpunk: edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %% [markdown]
# ## Lectura del archivo principal (netflix1):

# %%
df3 = pd.read_csv("netflix1.csv")

# %%
df3.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df3['listed_in'].unique()
# Out:
# array(['Documentaries',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'TV Dramas, TV Horror, TV Mysteries',
#        'Children & Family Movies, Comedies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Children & Family Movies, Comedies, Music & Musicals',
#        'Dramas, International Movies',
#        'Children & Family Movies, Music & Musicals',
#        'Dramas, International Movies, Music & Musicals', 'Movies',
#        'Comedies', 'Docuseries, Reality TV',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'Children & Family Movies', "Kids' TV",
#        'Documentaries, International Movies',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Comedies, International Movies, Romantic Movies',
#        'Horror Movies, Sci-Fi & Fantasy', 'Thrillers',
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# ``Cantidad de nulos de las columnas`` (df3 sin nulos)

# %%
df3.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# ``Función para cambiar la columna title a minúsculas`` (y evitar problemas en la vinculación de df)

# %%
def convertir_minusculas(df):
  
    if 'title' in df.columns:
        df['title'] = df['title'].str.lower()
    else:
        print("La columna 'title' no existe en el DataFrame.")
    
    return df

# %%
df3 = convertir_minusculas(df3)

# %%
df3.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              dick johnson is dead  Kirsten Johnson
# 1      s3  TV Show                         ganglands  Julien Leclercq
# 2      s6  TV Show                     midnight mass    Mike Flanagan
# 3     s14    Movie  confessions of an invisible girl    Bruno Garotti
# 4      s8    Movie                           sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %% [markdown]
# ``Vinculación de DataFrames``

# %%
# Tomamos df3 como el archivo principal y vinculamos a df

df_final= df3.merge(df, on='title', how='inner')

# %%
df_final.head()
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1      s3  TV Show             ganglands  Julien Leclercq         France
# 2      s6  TV Show         midnight mass    Mike Flanagan  United States
# 3      s6  TV Show         midnight mass    Mike Flanagan  United States
# 4      s6  TV Show         midnight mass    Mike Flanagan  United States
#
#   date_added  release_year rating_x duration_x  \
# 0  9/25/2021          2020    PG-13     90 min
# 1  9/24/2021          2021    TV-MA   1 Season
# 2  9/24/2021          2021    TV-MA   1 Season
# 3  9/24/2021          2021    TV-MA   1 Season
# 4  9/24/2021          2021    TV-MA   1 Season
#
#                                            listed_in      year certificate  \
# 0                                      Documentaries    (2020)       PG-13
# 1  Crime TV Shows, International TV Shows, TV Act...  (2021– )       TV-MA
# ...

# %%
df_final.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# country            0
# date_added         0
# release_year       0
# rating_x           0
# duration_x         0
# listed_in          0
# year              22
# certificate     1164
# duration_y       836
# genre              7
# rating_y         109
# description        0
# stars              0
# votes            109
# dtype: int64

# %%
df_final.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating_x', 'duration_x', 'listed_in', 'year',
#        'certificate', 'duration_y', 'genre', 'rating_y', 'description',
#        'stars', 'votes'],
#       dtype='object')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4993 entries, 0 to 4992
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4993 non-null   object
#  1   type          4993 non-null   object
#  2   title         4993 non-null   object
#  3   director      4993 non-null   object
#  4   country       4993 non-null   object
#  5   date_added    4993 non-null   object
#  6   release_year  4993 non-null   int64
#  7   rating_x      4993 non-null   object
#  8   duration_x    4993 non-null   object
#  9   listed_in     4993 non-null   object
#  10  year          4971 non-null   object
#  11  certificate   3829 non-null   object
#  12  duration_y    4157 non-null   object
#  13  genre         4986 non-null   object
#  14  rating_y      4884 non-null   float64
#  15  description   4993 non-null   object
#  16  stars         4993 non-null   object
#  17  votes         4884 non-null   object
# ...

# %% [markdown]
# ``Limpieza:``

# %% [markdown]
# **Columna date_added**
#
# - Hacer dos columnas. Una para mes/año.
# - Modificar columna a tipo int.

# %%
# Valores que alberga la columna date_added. Es una columna de tipo object

df_final["date_added"]
# Out:
# 0        9/25/2021
# 1        9/24/2021
# 2        9/24/2021
# 3        9/24/2021
# 4        9/24/2021
#            ...
# 4988      7/1/2017
# 4989     5/15/2020
# 4990      1/1/2016
# 4991    12/29/2018
# 4992     8/31/2018
# Name: date_added, Length: 4993, dtype: object

# %%
# Dividimos la columna en 3 nuevas columnas (mes, día, año)

split_cols = df_final['date_added'].str.split('/', expand=True) # expand=True hace que el resultado se guarde en columnas separadas

# Asignamos el mes y el año a las nuevas columnas que hemos creado y las convertimos a int

df_final['month_added'] = split_cols[0].astype(int) # split_cols[0] → Sobre la separación, cogemos la columna del mes   .astype(int) → convierte esos valores que están como texto a números
df_final['year_added'] = split_cols[2].astype(int)  # split_cols[2] → Sobre la separación, cogemos la columna del año

# %%
# Comprobamos que se han añadido las columnas month_added y year_added (al final del df)

df_final.head()
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1      s3  TV Show             ganglands  Julien Leclercq         France
# 2      s6  TV Show         midnight mass    Mike Flanagan  United States
# 3      s6  TV Show         midnight mass    Mike Flanagan  United States
# 4      s6  TV Show         midnight mass    Mike Flanagan  United States
#
#   date_added  release_year rating_x duration_x  \
# 0  9/25/2021          2020    PG-13     90 min
# 1  9/24/2021          2021    TV-MA   1 Season
# 2  9/24/2021          2021    TV-MA   1 Season
# 3  9/24/2021          2021    TV-MA   1 Season
# 4  9/24/2021          2021    TV-MA   1 Season
#
#                                            listed_in      year certificate  \
# 0                                      Documentaries    (2020)       PG-13
# 1  Crime TV Shows, International TV Shows, TV Act...  (2021– )       TV-MA
# ...

# %%
# Borramos la columna original (date_added) que ya no aporta valor

df_final = df_final.drop(columns=['date_added'])

# %% [markdown]
# **Columna duration** (PENDIENTE)

# %% [markdown]
# - Reemplazar min por espacio.
# - Cambiar a int.
# - Crear columna movies_duration(min) para saber que son minutos y no horas.
# - Con respecto a las series, crear una nueva columna llamada tv_series_duration(min) con las temporadas; debe ser de tipo int reemplazando "seasons" por espacio.

# %%
df_final["duration_x"].unique()
# Out:
# array(['90 min', '1 Season', '91 min', '125 min', '104 min', '127 min',
#        '61 min', '2 Seasons', '94 min', '111 min', '110 min', '105 min',
#        '106 min', '124 min', '116 min', '55 min', '23 min', '3 Seasons',
#        '182 min', '87 min', '92 min', '84 min', '97 min', '145 min',
#        '96 min', '119 min', '80 min', '273 min', '36 min', '95 min',
#        '4 Seasons', '82 min', '109 min', '77 min', '76 min', '107 min',
#        '93 min', '86 min', '70 min', '115 min', '122 min', '78 min',
#        '88 min', '102 min', '140 min', '64 min', '59 min', '114 min',
#        '60 min', '100 min', '34 min', '118 min', '7 Seasons', '112 min',
#        '132 min', '123 min', '101 min', '113 min', '46 min', '103 min',
#        '13 min', '138 min', '136 min', '39 min', '126 min', '98 min',
#        '133 min', '121 min', '89 min', '108 min', '159 min', '99 min',
#        '74 min', '49 min', '25 min', '73 min', '148 min', '85 min',
# ...

# %% [markdown]
# **Columna listed_in**

# %%
df_final["listed_in"].unique()
# Out:
# array(['Documentaries',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'TV Dramas, TV Horror, TV Mysteries',
#        'Children & Family Movies, Comedies',
#        'Dramas, Independent Movies, International Movies',
#        'Comedies, Dramas', 'Dramas, International Movies',
#        'Docuseries, Reality TV',
#        'British TV Shows, Crime TV Shows, Docuseries', "Kids' TV",
#        'Children & Family Movies',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure',
#        'TV Comedies', 'International TV Shows, TV Dramas, TV Thrillers',
#        'Reality TV',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        "Kids' TV, TV Comedies", 'Docuseries',
#        'International TV Shows, TV Comedies', 'Thrillers',
#        'Dramas, International Movies, Thrillers',
#        'Action & Adventure, Dramas, International Movies',
# ...

# %%
# Creamos una columna llamada "genre" donde irán los géneros de la columna "listed_in" (el primer elemento en el caso de salir varias categorías)

df_final['genre'] = df_final['listed_in'].str.split(',').str[0].str.strip()

# .str.split(','): divide la cadena por comas → genera una lista de categorías.
# .str[0]: selecciona el primer elemento de esa lista.
# .str.strip(): elimina espacios en blanco al inicio o final de la cadena.

# %%
df_final["genre"].unique()
# Out:
# array(['Documentaries', 'Crime TV Shows', 'TV Dramas',
#        'Children & Family Movies', 'Dramas', 'Comedies', 'Docuseries',
#        'British TV Shows', "Kids' TV", 'International TV Shows',
#        'TV Comedies', 'Reality TV', 'Thrillers', 'Action & Adventure',
#        'International Movies', 'Anime Series', 'Anime Features',
#        'Stand-Up Comedy', 'Stand-Up Comedy & Talk Shows', 'Horror Movies',
#        'TV Shows', 'Romantic TV Shows', 'Independent Movies',
#        'Music & Musicals', 'LGBTQ Movies', 'TV Action & Adventure',
#        'Classic & Cult TV', 'Classic Movies', 'Sci-Fi & Fantasy',
#        'Movies', 'TV Horror', 'Cult Movies', 'Romantic Movies',
#        'Spanish-Language TV Shows'], dtype=object)

# %%
# Borramos la columna listed_in que ya no nos sirve
df_final.drop(columns=['listed_in'], inplace=True)

# %%
# Comprobación de que la columna listed_in se ha borrado correctamente 
df_final.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'release_year',
#        'rating_x', 'duration_x', 'year', 'certificate', 'duration_y', 'genre',
#        'rating_y', 'description', 'stars', 'votes', 'month_added',
#        'year_added'],
#       dtype='object')

# %%
df_final.head()
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1      s3  TV Show             ganglands  Julien Leclercq         France
# 2      s6  TV Show         midnight mass    Mike Flanagan  United States
# 3      s6  TV Show         midnight mass    Mike Flanagan  United States
# 4      s6  TV Show         midnight mass    Mike Flanagan  United States
#
#    release_year rating_x duration_x      year certificate duration_y  \
# 0          2020    PG-13     90 min    (2020)       PG-13     89 min
# 1          2021    TV-MA   1 Season  (2021– )       TV-MA     44 min
# 2          2021    TV-MA   1 Season    (2021)       TV-MA    450 min
# 3          2021    TV-MA   1 Season    (2021)       TV-MA     59 min
# 4          2021    TV-MA   1 Season    (2021)       TV-MA     63 min
#
#             genre  rating_y  \
# 0   Documentaries       7.4
# 1  Crime TV Shows       7.0
# ...

# %% [markdown]
# **Columna show_id**

# %% [markdown]
# - Borramos esta columna; no aporta valor.

# %%
df_final.drop(columns=['show_id'], inplace=True)

# %%
# Comprobación de que la columna show_id se ha borrado correctamente 
df_final.columns
# Out:
# Index(['type', 'title', 'director', 'country', 'release_year', 'rating_x',
#        'duration_x', 'year', 'certificate', 'duration_y', 'genre', 'rating_y',
#        'description', 'stars', 'votes', 'month_added', 'year_added'],
#       dtype='object')

# %% [markdown]
# **Columna year**

# %% [markdown]
# - Borramos la columna; no aporta valor, tenemos los datos en "release_year"

# %%
df_final.drop(columns=['year'], inplace=True)

# %%
# Comprobación de que la columna year se ha borrado correctamente 
df_final.columns
# Out:
# Index(['type', 'title', 'director', 'country', 'release_year', 'rating_x',
#        'duration_x', 'certificate', 'duration_y', 'genre', 'rating_y',
#        'description', 'stars', 'votes', 'month_added', 'year_added'],
#       dtype='object')

# %% [markdown]
# **Columna description**

# %% [markdown]
# - Borramos la columna siguiendo documentación.

# %%
df_final.drop(columns=['description'], inplace=True)

# %%
# Comprobación de que la columna description se ha borrado correctamente 
df_final.columns
# Out:
# Index(['type', 'title', 'director', 'country', 'release_year', 'rating_x',
#        'duration_x', 'certificate', 'duration_y', 'genre', 'rating_y', 'stars',
#        'votes', 'month_added', 'year_added'],
#       dtype='object')

# %%
df_final.head()
# Out:
#       type                 title         director        country  \
# 0    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1  TV Show             ganglands  Julien Leclercq         France
# 2  TV Show         midnight mass    Mike Flanagan  United States
# 3  TV Show         midnight mass    Mike Flanagan  United States
# 4  TV Show         midnight mass    Mike Flanagan  United States
#
#    release_year rating_x duration_x certificate duration_y           genre  \
# 0          2020    PG-13     90 min       PG-13     89 min   Documentaries
# 1          2021    TV-MA   1 Season       TV-MA     44 min  Crime TV Shows
# 2          2021    TV-MA   1 Season       TV-MA    450 min       TV Dramas
# 3          2021    TV-MA   1 Season       TV-MA     59 min       TV Dramas
# 4          2021    TV-MA   1 Season       TV-MA     63 min       TV Dramas
#
#    rating_y                                              stars    votes  \
# ...

# %% [markdown]
# **Columna rating_x**

# %% [markdown]
# - Renombramos columna a "age_rating" (docu: recordamos que esta columna representa la clasificación por edad)

# %%
df_final = df_final.rename(columns={'rating_x': 'age_rating'})

# %%
# Comprobación de que la columna rating_x ha cambiado a age_rating
df_final.columns
# Out:
# Index(['type', 'title', 'director', 'country', 'release_year', 'age_rating',
#        'duration_x', 'certificate', 'duration_y', 'genre', 'rating_y', 'stars',
#        'votes', 'month_added', 'year_added'],
#       dtype='object')

# %%
df_final.head()
# Out:
#       type                 title         director        country  \
# 0    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1  TV Show             ganglands  Julien Leclercq         France
# 2  TV Show         midnight mass    Mike Flanagan  United States
# 3  TV Show         midnight mass    Mike Flanagan  United States
# 4  TV Show         midnight mass    Mike Flanagan  United States
#
#    release_year age_rating duration_x certificate duration_y           genre  \
# 0          2020      PG-13     90 min       PG-13     89 min   Documentaries
# 1          2021      TV-MA   1 Season       TV-MA     44 min  Crime TV Shows
# 2          2021      TV-MA   1 Season       TV-MA    450 min       TV Dramas
# 3          2021      TV-MA   1 Season       TV-MA     59 min       TV Dramas
# 4          2021      TV-MA   1 Season       TV-MA     63 min       TV Dramas
#
#    rating_y                                              stars    votes  \
# ...

# %% [markdown]
# **Columna votes**

# %% [markdown]
# - Sustitumos comas por espacios y modificamos tipo de dato de object a int.

# %%
# Confirmamos que hay que cambiar las comas por puntos
df_final["votes"].unique()
# Out:
# array(['6,636', '2,640', '110,997', ..., '196,192', '13,133', '23,865'],
#       dtype=object)

# %%
# Confirmamos que la columna es tipo object
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4993 entries, 0 to 4992
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          4993 non-null   object
#  1   title         4993 non-null   object
#  2   director      4993 non-null   object
#  3   country       4993 non-null   object
#  4   release_year  4993 non-null   int64
#  5   age_rating    4993 non-null   object
#  6   duration_x    4993 non-null   object
#  7   certificate   3829 non-null   object
#  8   duration_y    4157 non-null   object
#  9   genre         4993 non-null   object
#  10  rating_y      4884 non-null   float64
#  11  stars         4993 non-null   object
#  12  votes         4884 non-null   object
#  13  month_added   4993 non-null   int32
#  14  year_added    4993 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(11)
# memory usage: 546.2+ KB

# %%
# Nulos de la columna "votes": 109
df_final.isnull().sum()
# Out:
# type               0
# title              0
# director           0
# country            0
# release_year       0
# age_rating         0
# duration_x         0
# certificate     1164
# duration_y       836
# genre              0
# rating_y         109
# stars              0
# votes            109
# month_added        0
# year_added         0
# dtype: int64

# %%
# Porcentaje de nulos en la columna "votes": 2.18 %
null_porcentaje = df_final['votes'].isnull().mean() * 100
print(f"Porcentaje de valores nulos en 'votes': {null_porcentaje:.2f}%")
# Out:
# Porcentaje de valores nulos en 'votes': 2.18%

# %%
# Cambiamos comas por puntos (en filas con valor)
df_final['votes'] = df_final['votes'].str.replace(',', '', regex=False)

# %%
df_final["votes"].unique()
# Out:
# array(['6636', '2640', '110997', ..., '196192', '13133', '23865'],
#       dtype=object)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4993 entries, 0 to 4992
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          4993 non-null   object
#  1   title         4993 non-null   object
#  2   director      4993 non-null   object
#  3   country       4993 non-null   object
#  4   release_year  4993 non-null   int64
#  5   age_rating    4993 non-null   object
#  6   duration_x    4993 non-null   object
#  7   certificate   3829 non-null   object
#  8   duration_y    4157 non-null   object
#  9   genre         4993 non-null   object
#  10  rating_y      4884 non-null   float64
#  11  stars         4993 non-null   object
#  12  votes         4884 non-null   object
#  13  month_added   4993 non-null   int32
#  14  year_added    4993 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(11)
# memory usage: 546.2+ KB

# %%
# Sustituimos los NaN por 0 y cambiamos la columna a tipo int
df_final['votes'] = df_final['votes'].fillna(0).astype(int)

# %%
# Comrpobacion del cambio de tipo de dato de la columna
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4993 entries, 0 to 4992
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          4993 non-null   object
#  1   title         4993 non-null   object
#  2   director      4993 non-null   object
#  3   country       4993 non-null   object
#  4   release_year  4993 non-null   int64
#  5   age_rating    4993 non-null   object
#  6   duration_x    4993 non-null   object
#  7   certificate   3829 non-null   object
#  8   duration_y    4157 non-null   object
#  9   genre         4993 non-null   object
#  10  rating_y      4884 non-null   float64
#  11  stars         4993 non-null   object
#  12  votes         4993 non-null   int32
#  13  month_added   4993 non-null   int32
#  14  year_added    4993 non-null   int32
# dtypes: float64(1), int32(3), int64(1), object(10)
# memory usage: 526.7+ KB

# %% [markdown]
# **Columna rating_y**

# %% [markdown]
# - Renombramos columna a "rating" para que no haya confusión con "rating_x", que actualmente se llama "age_rating"

# %%
df_final["rating_y"].unique()
# Out:
# array([7.4, 7. , 7.7, 7.3, 8.1, 8. , 8.6, 5.2, 6.3, 5.5, 6.7, 7.1, 6.8,
#        5.8, 6.2, 6.1, 5.7, 5.4, 5.6, 7.9, 8.5, 8.4, 8.7, 8.8, 8.2, 6.9,
#        nan, 6.6, 6.5, 6.4, 4.9, 4.7, 7.6, 7.2, 5.9, 4.3, 5.3, 4.6, 7.5,
#        7.8, 4.8, 5.1, 8.3, 8.9, 4.4, 6. , 3.8, 3.3, 4. , 3.9, 4.2, 5. ,
#        4.5, 3.1, 3.7, 3.2, 3.6, 2.8, 3.5, 9.2, 9.1, 2.7, 4.1, 2.5, 2.6,
#        2.3, 3.4, 2. , 9. , 2.9, 3. , 9.3, 9.4, 9.6, 9.5, 2.4, 9.9])

# %%
df_final.rename(columns={'rating_y': 'rating'}, inplace=True)

# %%
# Comprobamos que se ha modificado el nombre de la columna correctamente
df_final.columns
# Out:
# Index(['type', 'title', 'director', 'country', 'release_year', 'age_rating',
#        'duration_x', 'certificate', 'duration_y', 'genre', 'rating', 'stars',
#        'votes', 'month_added', 'year_added'],
#       dtype='object')

# %% [markdown]
# **Columna stars**

# %%
df_final["stars"].unique()
# Out:
# array(["['Kirsten Johnson', '| ', '    Stars:', 'Michael Hilow, ', 'Ana Hoffman, ', 'Dick Johnson, ', 'Kirsten Johnson']",
#        "['Tracy Gotoas, ', 'Sofia Lesaffre, ', 'Salim Kechiouche, ', 'Noureddine Farihi']",
#        "['Kate Siegel, ', 'Zach Gilford, ', 'Kristin Lehman, ', 'Samantha Sloyan']",
#        ...,
#        "['Michael Hollander, ', 'Michael Sorich, ', 'David Carr, ', 'Gardner Baldwin']",
#        "['Erin Krakow, ', 'Martin Cummins, ', 'Pascale Hutton, ', 'Jack Wagner']",
#        "['Vishesh Bansal, ', 'Mona Singh, ', 'Akarsh Khurana, ', 'Ahan Nirban']"],
#       dtype=object)

# %%
# Sustituimos los elementos que no nos sirven por espacio

df_final['stars'] = df_final['stars'].str.replace("Stars:", "", regex=False)\
                                     .str.replace("|", "", regex=False)\
                                     .str.replace("[", "", regex=False)\
                                     .str.replace("]", "", regex=False)\
                                     .str.replace("'", "", regex=False)\
                                     .str.strip()

# %%
# Comprobamos que todavia queda limpieza por hacer
df_final["stars"].unique()
# Out:
# array(['Kirsten Johnson,  ,     , Michael Hilow, , Ana Hoffman, , Dick Johnson, , Kirsten Johnson',
#        'Tracy Gotoas, , Sofia Lesaffre, , Salim Kechiouche, , Noureddine Farihi',
#        'Kate Siegel, , Zach Gilford, , Kristin Lehman, , Samantha Sloyan',
#        ...,
#        'Michael Hollander, , Michael Sorich, , David Carr, , Gardner Baldwin',
#        'Erin Krakow, , Martin Cummins, , Pascale Hutton, , Jack Wagner',
#        'Vishesh Bansal, , Mona Singh, , Akarsh Khurana, , Ahan Nirban'],
#       dtype=object)

# %%
df_final['stars'] = df_final['stars'].str.split(',').apply(lambda x: ', '.join([i.strip() for i in x if i.strip()]))

# .str.split(','): Divide el texto por comas.
# .apply(): Limpia los espacios adicionales de cada elemento y elimina los vacíos.
# .join(): Vuelve a juntar los nombres con comas.

# %%
df_final.head()
# Out:
#       type                 title         director        country  \
# 0    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1  TV Show             ganglands  Julien Leclercq         France
# 2  TV Show         midnight mass    Mike Flanagan  United States
# 3  TV Show         midnight mass    Mike Flanagan  United States
# 4  TV Show         midnight mass    Mike Flanagan  United States
#
#    release_year age_rating duration_x certificate duration_y           genre  \
# 0          2020      PG-13     90 min       PG-13     89 min   Documentaries
# 1          2021      TV-MA   1 Season       TV-MA     44 min  Crime TV Shows
# 2          2021      TV-MA   1 Season       TV-MA    450 min       TV Dramas
# 3          2021      TV-MA   1 Season       TV-MA     59 min       TV Dramas
# 4          2021      TV-MA   1 Season       TV-MA     63 min       TV Dramas
#
#    rating                                              stars   votes  \
# ...

# %%
df_final["stars"].unique()
# Out:
# array(['Kirsten Johnson, Michael Hilow, Ana Hoffman, Dick Johnson, Kirsten Johnson',
#        'Tracy Gotoas, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi',
#        'Kate Siegel, Zach Gilford, Kristin Lehman, Samantha Sloyan', ...,
#        'Michael Hollander, Michael Sorich, David Carr, Gardner Baldwin',
#        'Erin Krakow, Martin Cummins, Pascale Hutton, Jack Wagner',
#        'Vishesh Bansal, Mona Singh, Akarsh Khurana, Ahan Nirban'],
#       dtype=object)

# %%
# Nos quedamos con el primer actor de cada cadena de texto
df_final['stars'] = df_final['stars'].str.split(',').str[0].str.strip()

# %%
# Confirmamos los cambios
df_final["stars"].unique()
# Out:
# array(['Kirsten Johnson', 'Tracy Gotoas', 'Kate Siegel', ...,
#        'Michael Hollander', 'Erin Krakow', 'Vishesh Bansal'], dtype=object)

# %%
df_final.head()
# Out:
#       type                 title         director        country  \
# 0    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1  TV Show             ganglands  Julien Leclercq         France
# 2  TV Show         midnight mass    Mike Flanagan  United States
# 3  TV Show         midnight mass    Mike Flanagan  United States
# 4  TV Show         midnight mass    Mike Flanagan  United States
#
#    release_year age_rating duration_x certificate duration_y           genre  \
# 0          2020      PG-13     90 min       PG-13     89 min   Documentaries
# 1          2021      TV-MA   1 Season       TV-MA     44 min  Crime TV Shows
# 2          2021      TV-MA   1 Season       TV-MA    450 min       TV Dramas
# 3          2021      TV-MA   1 Season       TV-MA     59 min       TV Dramas
# 4          2021      TV-MA   1 Season       TV-MA     63 min       TV Dramas
#
#    rating            stars   votes  month_added  year_added
# ...

# %% [markdown]
# **Filas duplicadas**

# %%
# Vemos todas las filas duplicadas en el DataFrame
df_final[df_final.duplicated()]
# Out:
#          type                        title     director         country  \
# 194   TV Show                    hero mask    Not Given        Pakistan
# 376   TV Show                    feel good  Ally Pankiw  United Kingdom
# 2503  TV Show              the worst witch    Not Given  United Kingdom
# 3141  TV Show                 sneakerheads    Not Given   United States
# 3468  TV Show  the queen and the conqueror    Not Given        Colombia
# ...       ...                          ...          ...             ...
# 4402  TV Show            go! live your way    Not Given       Argentina
# 4403  TV Show            go! live your way    Not Given       Argentina
# 4409  TV Show            go! live your way    Not Given       Argentina
# 4410  TV Show            go! live your way    Not Given       Argentina
# 4411  TV Show            go! live your way    Not Given       Argentina
#
#       release_year age_rating duration_x certificate duration_y  \
# ...

# %%
# Filas y columnas totales antes del cambio
df_final.shape
# Out:
# (4993, 15)

# %%
# Eliminamos las filas duplicadas, manteniendo la primera ocurrencia con el parámetro keep=first
df_final = df_final.drop_duplicates(keep='first')

# %%
# Filas y columnas totales después del cambio
df_final.shape
# Out:
# (4919, 15)

# %%
# Confirmamos que ya no quedan filas duplicadas en el dataframe
df_final[df_final.duplicated()]
# Out:
# Empty DataFrame
# Columns: [type, title, director, country, release_year, age_rating, duration_x, certificate, duration_y, genre, rating, stars, votes, month_added, year_added]
# Index: []

# %% [markdown]
# **Columna certificate**

# %% [markdown]
# - Buscamos info de las clasificaciones actuales de EEUU y descrubrimos que las categorías "unrated"/"not rated"/"approved"/"passed" pertenecen a la clasificación antigua que se hacía, sustituida por PG-13/TV-MA y demás.
# - Comparamos los valores únicos de la columna "certificate" y "age_rating" (anteriormente rating_x) y vemos que apenas se pierde información.
# - Decidimos borrar la columna "certificate"

# %%
# Comparamos los valores únicos de la columna "certificate"
df_final["certificate"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'TV-PG', nan, 'PG', 'TV-14', 'TV-Y', 'TV-G',
#        'TV-Y7', 'R', 'Not Rated', 'TV-Y7-FV', '12', 'Unrated', 'G',
#        'Approved', 'NC-17', 'Passed'], dtype=object)

# %%
# Comparamos los valores únicos de la columna "age_rating" (anteriormente rating_x)
df_final["age_rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'TV-PG', 'TV-Y', 'PG', 'TV-14', 'TV-Y7', 'TV-G',
#        'R', 'G', 'NC-17', 'NR'], dtype=object)

# %%
# Nulos de la columna "certificate": 1104. 
# Nulos de la columna "age_rating": 0
df_final.isnull().sum()
# Out:
# type               0
# title              0
# director           0
# country            0
# release_year       0
# age_rating         0
# duration_x         0
# certificate     1103
# duration_y       766
# genre              0
# rating            51
# stars              0
# votes              0
# month_added        0
# year_added         0
# dtype: int64

# %%
# Borramos la columna "certificate" para quedarnos con age_rating
df_final.drop(columns=['certificate'], inplace=True)

# %%
# Comprobamos que se ha borrado correctamente
df_final.columns
# Out:
# Index(['type', 'title', 'director', 'country', 'release_year', 'age_rating',
#        'duration_x', 'duration_y', 'genre', 'rating', 'stars', 'votes',
#        'month_added', 'year_added'],
#       dtype='object')

# %%
df_final.head()
# Out:
#       type                 title         director        country  \
# 0    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1  TV Show             ganglands  Julien Leclercq         France
# 2  TV Show         midnight mass    Mike Flanagan  United States
# 3  TV Show         midnight mass    Mike Flanagan  United States
# 4  TV Show         midnight mass    Mike Flanagan  United States
#
#    release_year age_rating duration_x duration_y           genre  rating  \
# 0          2020      PG-13     90 min     89 min   Documentaries     7.4
# 1          2021      TV-MA   1 Season     44 min  Crime TV Shows     7.0
# 2          2021      TV-MA   1 Season    450 min       TV Dramas     7.7
# 3          2021      TV-MA   1 Season     59 min       TV Dramas     7.3
# 4          2021      TV-MA   1 Season     63 min       TV Dramas     7.7
#
#              stars   votes  month_added  year_added
# 0  Kirsten Johnson    6636            9        2021
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4919 entries, 0 to 4992
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          4919 non-null   object
#  1   title         4919 non-null   object
#  2   director      4919 non-null   object
#  3   country       4919 non-null   object
#  4   release_year  4919 non-null   int64
#  5   age_rating    4919 non-null   object
#  6   duration_x    4919 non-null   object
#  7   duration_y    4153 non-null   object
#  8   genre         4919 non-null   object
#  9   rating        4868 non-null   float64
#  10  stars         4919 non-null   object
#  11  votes         4919 non-null   int32
#  12  month_added   4919 non-null   int32
#  13  year_added    4919 non-null   int32
# dtypes: float64(1), int32(3), int64(1), object(9)
# memory usage: 518.8+ KB

# %% [markdown]
# **Columna duration_x**

# %%
# Crear duration_min: si duration menciona minutos, extrae número, si no, pone 0
df_final['duration_min'] = df_final['duration_x'].apply(
    lambda x: int(x.split()[0]) if isinstance(x, str) and 'min' in x.lower() else 0)

# %%
# Crear season_count: si duration menciona season, extrae número, si no, pone 0
df_final['seasons'] = df_final['duration_x'].apply(
    lambda x: int(x.split()[0]) if isinstance(x, str) and 'season' in x.lower() else 0)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4919 entries, 0 to 4992
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          4919 non-null   object
#  1   title         4919 non-null   object
#  2   director      4919 non-null   object
#  3   country       4919 non-null   object
#  4   release_year  4919 non-null   int64
#  5   age_rating    4919 non-null   object
#  6   duration_x    4919 non-null   object
#  7   duration_y    4153 non-null   object
#  8   genre         4919 non-null   object
#  9   rating        4868 non-null   float64
#  10  stars         4919 non-null   object
#  11  votes         4919 non-null   int32
#  12  month_added   4919 non-null   int32
#  13  year_added    4919 non-null   int32
#  14  duration_min  4919 non-null   int64
#  15  seasons       4919 non-null   int64
# dtypes: float64(1), int32(3), int64(3), object(9)
# memory usage: 595.7+ KB

# %%
# Eliminar la columna original duration_x
df_final = df_final.drop(columns=['duration_x'])

# %% [markdown]
# **Columna duration_y**

# %% [markdown]
# - Borramos la columna

# %%
# Eliminar la columna original duration
df_final = df_final.drop(columns=['duration_y'])

# %%
df_final.columns
# Out:
# Index(['type', 'title', 'director', 'country', 'release_year', 'age_rating',
#        'genre', 'rating', 'stars', 'votes', 'month_added', 'year_added',
#        'duration_min', 'seasons'],
#       dtype='object')

# %% [markdown]
# **Gestión de nulos en las columnas resultantes**

# %%
# Nulos resultantes por columna
df_final.isnull().sum()
# Out:
# type             0
# title            0
# director         0
# country          0
# release_year     0
# age_rating       0
# genre            0
# rating          51
# stars            0
# votes            0
# month_added      0
# year_added       0
# duration_min     0
# seasons          0
# dtype: int64

# %%
# Columna rating: sustituimos nulos por 0
df_final['rating'] = df_final['rating'].fillna(0)

# %%
# Comprobación de los cambios realizados
df_final.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# country         0
# release_year    0
# age_rating      0
# genre           0
# rating          0
# stars           0
# votes           0
# month_added     0
# year_added      0
# duration_min    0
# seasons         0
# dtype: int64

# %%
df_final.head()
# Out:
#       type                 title         director        country  \
# 0    Movie  dick johnson is dead  Kirsten Johnson  United States
# 1  TV Show             ganglands  Julien Leclercq         France
# 2  TV Show         midnight mass    Mike Flanagan  United States
# 3  TV Show         midnight mass    Mike Flanagan  United States
# 4  TV Show         midnight mass    Mike Flanagan  United States
#
#    release_year age_rating           genre  rating            stars   votes  \
# 0          2020      PG-13   Documentaries     7.4  Kirsten Johnson    6636
# 1          2021      TV-MA  Crime TV Shows     7.0     Tracy Gotoas    2640
# 2          2021      TV-MA       TV Dramas     7.7      Kate Siegel  110997
# 3          2021      TV-MA       TV Dramas     7.3    Mike Flanagan    3841
# 4          2021      TV-MA       TV Dramas     7.7    Mike Flanagan    3523
#
#    month_added  year_added  duration_min  seasons
# 0            9        2021            90        0
# ...

# %%
df_final.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# country         0
# release_year    0
# age_rating      0
# genre           0
# rating          0
# stars           0
# votes           0
# month_added     0
# year_added      0
# duration_min    0
# seasons         0
# dtype: int64

# %%
df_final.to_csv('analisis_netflix_final.csv', index=False)
